# %%
pip install power_security_lib

# %%
from power_security_lib import PowerInfrastructureAnalyzer, run_full_assessment

# Quick one-line assessment with all steps
analyzer = run_full_assessment(
    location_name="Stanford University, California, USA",
    buffer_distance=1.5,
    save_visualization="output/stanford_map.png",
    save_report="output/stanford_report.html",
    report_format="html"
)

# Or step-by-step with more control
analyzer = PowerInfrastructureAnalyzer(
    place_name="MIT, Cambridge, Massachusetts",
    buffer_distance=2.0
)

# Run individual steps as needed
analyzer.retrieve_infrastructure_data()
analyzer.identify_critical_assets()
analyzer.assess_vulnerabilities()
analyzer.develop_security_strategy()
analyzer.visualize_infrastructure(save_path="output/mit_map.png")
report = analyzer.generate_report(output_format="markdown", save_path="output/mit_report.md")
# Out:
# Starting analysis for: Stanford University, California, USA
# Buffer distance: 1.5 km
#
# Step 1: Retrieving infrastructure data...
# Geocoding Stanford University, California, USA to obtain its boundary...
# Expanded search area with a 1.5 km buffer...
# Querying power infrastructure features within the expanded boundary...
# Retrieving road network for vulnerability assessment...
# Retrieving buildings for vulnerability assessment...
#
# Step 2: Identifying critical assets...
# Found 2 substations
# Found 223 lines
# Found 7 transformers
# Found 887 poles
# Found 0 towers
# Total critical assets identified: 1119
#
# Step 3: Performing vulnerability assessment...
# Performing vulnerability assessment for threat: cyber-physical intrusion
#
# Step 4: Developing security strategy...
#
# Step 5: Generating visualization...
# Could not retrieve street network: plot_graph() got an unexpected keyword argument 'zorder'
# Visualization saved to: output/stanford_map.png
# Visualization saved to: output/stanford_map.png
#
# Step 6: Generating vulnerability assessment report...
# Report saved to: output/stanford_report.html
# Report saved to: output/stanford_report.html
# Geocoding MIT, Cambridge, Massachusetts to obtain its boundary...
# Expanded search area with a 2.0 km buffer...
# Querying power infrastructure features within the expanded boundary...
# Retrieving road network for vulnerability assessment...
# Retrieving buildings for vulnerability assessment...
# Found 10 substations
# Found 7 lines
# Found 9 transformers
# Found 23 poles
# Found 0 towers
# Performing vulnerability assessment for threat: cyber-physical intrusion
# Could not retrieve street network: plot_graph() got an unexpected keyword argument 'zorder'
# Visualization saved to: output/mit_map.png
# Report saved to: output/mit_report.md
